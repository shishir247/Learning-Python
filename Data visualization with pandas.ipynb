# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot(figsize=(15,10), title="iris data")
# Out:
# <AxesSubplot:title={'center':'iris data'}>

# %%
object = iris.plot(figsize=(15,10), title="iris data")
object.set_xlabel("by default it will take index in x axis")
object.set_ylabel("it will take rest of numerical columns")
# Out:
# Text(0, 0.5, 'it will take rest of numerical columns')

# %%
iris.plot(figsize=(10,5), kind = "bar")
# Out:
# <AxesSubplot:>

# %%
iris.plot(figsize=(10,5), kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df = iris.drop("species", axis = 1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.pclass.plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic.pclass.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
from numpy.random import randn
df = pd.DataFrame(randn(10,4), columns=["a","b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  1.554436 -1.231791 -0.323127  0.751859
# 1  0.082311 -0.232100 -0.879468 -0.602909
# 2 -0.301801 -0.867992  0.693661  0.152693
# 3 -0.685374  1.829508  1.518288 -1.003087
# 4 -1.465894  2.135844 -0.564342 -0.385791
# 5  1.792660 -0.682569  1.046784 -0.690979
# 6 -0.799929 -1.988453  1.714795 -0.305866
# 7 -0.269235 -0.689494  0.151602 -0.180750
# 8 -0.179565  1.249560 -0.549286 -0.582292
# 9  1.049530  0.328724 -0.161695 -0.620457

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris["sepal_length"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = "hist", stacked = True, alpha = 0.2)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = "hist", stacked = True, bins = 50, alpha = 0.3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind = "hist", stacked = True, bins = 50, orientation = "horizontal")
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.head()
# Out:
#           a         b         c         d
# 0  1.554436 -1.231791 -0.323127  0.751859
# 1  0.082311 -0.232100 -0.879468 -0.602909
# 2 -0.301801 -0.867992  0.693661  0.152693
# 3 -0.685374  1.829508  1.518288 -1.003087
# 4 -1.465894  2.135844 -0.564342 -0.385791

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(color = "y", alpha = 0.21, figsize=(10,10))
#aplha is intensity of color
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.hist(figsize=(10,10))
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\numpy\lib\histograms.py in _unsigned_subtract(a, b)
#     353     try:
# --> 354         dt = signed_to_unsigned[dt.type]
#     355     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-1c1500f87371> in <module>
# ----> 1 titanic.hist(figsize=(10,10))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     225         legend=legend,
#     226         bins=bins,
# ...

# %%
df
# Out:
#           a         b         c         d
# 0  1.554436 -1.231791 -0.323127  0.751859
# 1  0.082311 -0.232100 -0.879468 -0.602909
# 2 -0.301801 -0.867992  0.693661  0.152693
# 3 -0.685374  1.829508  1.518288 -1.003087
# 4 -1.465894  2.135844 -0.564342 -0.385791
# 5  1.792660 -0.682569  1.046784 -0.690979
# 6 -0.799929 -1.988453  1.714795 -0.305866
# 7 -0.269235 -0.689494  0.151602 -0.180750
# 8 -0.179565  1.249560 -0.549286 -0.582292
# 9  1.049530  0.328724 -0.161695 -0.620457

# %%
df.plot.scatter(x = "a", y = "b")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.plot.scatter(x="sepal_length", y="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = "sepal_length", y = "petal_length", c = "sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = "sepal_length", y = "petal_length", s = 15)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.scatter(x = "sepal_length", y = "petal_length", s = 50) 
# s gives size of dots
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
a = iris.drop("species",axis =1).iloc[0]
print(a)
print(type(a))
a.plot.pie(figsize=(10,10))
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64
# <class 'pandas.core.series.Series'>
# <AxesSubplot:ylabel='0'>

# %%
a = iris.drop("species", axis = 1).head(3).T
a
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
b = iris.drop("species", axis = 1).iloc[0:3].T
b
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
b.plot.pie(subplots = True, figsize = (25,25))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
b.plot.pie(subplots = True, figsize = (20,20), fontsize = 20, autopct = "%.3f")
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris, figsize=(10,10), s = 50)
plt.show()

# %%
scatter_matrix(iris, figsize=(10,10), diagonal = "kde", s = 50)
plt.show()

# %%
sns.pairplot(iris)

# %%
iris.plot(subplots = True, figsize = (10,10))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
iris.plot(subplots = True, figsize = (15,10), layout = (2,3))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
iris.plot(kind = "box")
# Out:
# <AxesSubplot:>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', data = iris, hue = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...
